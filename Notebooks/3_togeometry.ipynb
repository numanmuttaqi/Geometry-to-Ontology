# %%
import sys, pathlib
repo_root = pathlib.Path("/Users/muhammadnumanmuttaqi/Documents/MScITBE/Thesis/Thesis/Geometry-to-Ontology")
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %% [markdown]
# # TTL to Geometry

# %% [markdown]
# # Wall

# %%
from thesis_package.ttl_to_json import save_ttl_as_json
from thesis_package.visualize import plot_plan_json

print("\nRegenerating...")
save_ttl_as_json(
    "../output/inferred_resplan_ttl/plan_00000_walls_back.ttl",
    "../output/inferred_resplan_json/plan_00000_walls_back.json",
)

print("\nVisualizing...")
plot_plan_json("../output/inferred_resplan_json/plan_00000_walls_back.json")
# Out:
# Regenerating...
#  IW-INF-8b808cd9-dff8-43ef-9f02-26524d698d97 (BED-01↔BTH-02): VERTICAL, L=1.257m, 3 openings
#  IW-INF-3ffee250-c9b1-41ef-9d84-db7c2f7ceff5 (BED-01↔BTH-01): VERTICAL, L=1.612m, 2 openings
#  IW-INF-95c5a0a1-95c6-4093-a8f8-1f38002b1cee (BED-01↔BTH-02): HORIZONTAL, L=0.474m, 3 openings
#
# Visualizing...
# <Axes: title={'center': 'Plan #0'}>

# %% [markdown]
# # Door

# %%
from thesis_package.ttl_to_json import save_ttl_as_json
from thesis_package.visualize import plot_plan_json


save_ttl_as_json(
    "../output/inferred_resplan_ttl/plan_00005_doors_back.ttl",
    "../output/inferred_resplan_json/plan_00005_doors_back.json",
)

ax = plot_plan_json("../output/inferred_resplan_json/plan_00005_doors_back.json",
                    show_wall_ids=True, show_ids=True)
# Out:
# === DEBUG DOOR 9206ca5b892c7d7a580a ===
#   Nearest points: pA=(7.016683506997319, 1.021084540197371), pB=(7.016683506997319, 1.021084540197371)
#   dx=0.000, dy=0.000
#   Wall A bounds: x=[7.017, 7.226], y=[0.131, 1.021]
#   Wall B bounds: x=[7.017, 7.226], y=[1.021, 3.046]
#   Orientation: VERTICAL
#   Room 1 bounds: x=[5.463, 10.804]
#   Room 2 bounds: x=[5.463, 7.052]
#   Base x: 7.017, Edge (room2_right): 7.052
#   Using weighted (w=0): 7.052
#   Door line: (7.052, 1.021) → (7.052, 1.021)
#   Thickness: 0.209
#   Door poly bounds: (nan, nan, nan, nan)
#
# === DEBUG DOOR 5aa1b74331ebbd123e71 ===
#   Nearest points: pA=(7.889405336225841, 4.686516222957165), pB=(7.889405336225841, 4.686516222957165)
#   dx=0.000, dy=0.000
#   Wall A bounds: x=[7.889, 8.099], y=[4.512, 4.687]
#   Wall B bounds: x=[7.889, 10.979], y=[4.687, 4.896]
#   Orientation: VERTICAL
#   Room 1 bounds: x=[5.463, 10.804]
#   Room 2 bounds: x=[1.536, 7.924]
#   Base x: 7.889, Edge (room2_right): 7.924
#   Using weighted (w=0): 7.924
#   Door line: (7.924, 4.687) → (7.924, 4.687)
#   Thickness: 0.175
#   Door poly bounds: (nan, nan, nan, nan)
#
# === DEBUG DOOR ab605619cff7d23b7a13 ===
#   Nearest points: pA=(1.57089929261134, 5.7381460271775335), pB=(1.57089929261134, 6.53232289177549)
#   dx=0.000, dy=0.794
#   Wall A bounds: x=[1.361, 1.571], y=[4.233, 5.738]
#   Wall B bounds: x=[1.361, 1.571], y=[6.532, 7.776]
#   Orientation: VERTICAL
#   Room 1 bounds: x=[0.035, 1.361]
#   Room 2 bounds: x=[1.536, 7.924]
#   Base x: 1.571, Edge (room2_left): 1.536
#   Using weighted (w=0): 1.536
#   No Y overlap, using gap
#   Door line: (1.536, 5.738) → (1.536, 6.532)
#   Thickness: 0.209
#   Door poly bounds: (1.4312637999347768, 5.7381460271775335, 1.640717038949622, 6.53232289177549)

# %% [markdown]
# # Window

# %%
from thesis_package.ttl_to_json import save_ttl_as_json
from thesis_package.visualize import plot_plan_json


save_ttl_as_json(
    "../output/inferred_resplan_ttl/plan_00009_windows_back.ttl",
    "../output/inferred_resplan_json/plan_00009_windows_back.json",
)

ax = plot_plan_json("../output/inferred_resplan_json/plan_00009_windows_back.json",
                    show_wall_ids=True, show_ids=True)
# Out:
# === DEBUG WINDOW WI-INF-7695acbd71232838684ca2f7d8ba792da704de768f2a21f66eb7bc42185bb6ae ===
#   Primary wall: EX-27
#   Primary bounds: (-0.5154087457337768, 21.698708195392005, 0.10308174914675537, 22.677984812286184)
#   All host walls: ['EX-24', 'EX-27']
#   Secondary wall: EX-24
#   Secondary bounds: (1.0308174914675536, 19.740154961603654, 2.164716732081863, 20.358645456484187)
#   Orientation: VERTICAL, thickness=0.618
#   Axis: [(-0.20616349829351072, 21.698708195392005), (-0.20616349829351072, 22.677984812286184)]
#   Distance to axis start: 1.824, to end: 2.629
#   Anchor: START (-0.20616349829351072, 21.698708195392005)
#   Window length: raw=1.824, clamped=1.824
#   Nearest on secondary: (1.0308174914675536, 20.358645456484187)
#   Window line (V): (-0.206, 21.699) → (-0.206, 19.875)
#   ✅ Window created: area=1.128, geom_type=Polygon
#   ✅ Result keys: dict_keys(['type', 'coordinates'])
#   ✅ Result type: Polygon
