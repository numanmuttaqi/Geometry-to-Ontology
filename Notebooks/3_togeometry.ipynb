# %%
import sys, pathlib
repo_root = pathlib.Path("/Users/muhammadnumanmuttaqi/Documents/MScITBE/Thesis/Thesis/Geometry-to-Ontology")
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %% [markdown]
# # TTL to Geometry

# %% [markdown]
# # Wall

# %%
from thesis_package.ttl_to_json import ttl_to_plan_dict, save_ttl_as_json

# regen JSON dengan kode terbaru
save_ttl_as_json(
    "../output/inferred_resplan_ttl/plan_00000_walls_back.ttl",
    "../output/inferred_resplan_json/plan_00000_walls_back.json",
)

plan = ttl_to_plan_dict("../output/inferred_resplan_ttl/plan_00000_walls_back.ttl")
walls = plan["instances"]["structural"]["interior_wall"]
# Out:
#  IW-INF-3ffee250-c9b1-41ef-9d84-db7c2f7ceff5 (BED-01↔BTH-01): VERTICAL, L=1.612m, 2 openings
#  IW-INF-8b808cd9-dff8-43ef-9f02-26524d698d97 (BED-01↔BTH-02): VERTICAL, L=1.257m, 3 openings
#  IW-INF-95c5a0a1-95c6-4093-a8f8-1f38002b1cee (BED-01↔BTH-02): HORIZONTAL, L=0.474m, 3 openings
#  IW-INF-3ffee250-c9b1-41ef-9d84-db7c2f7ceff5 (BED-01↔BTH-01): VERTICAL, L=1.612m, 2 openings
#  IW-INF-8b808cd9-dff8-43ef-9f02-26524d698d97 (BED-01↔BTH-02): VERTICAL, L=1.257m, 3 openings
#  IW-INF-95c5a0a1-95c6-4093-a8f8-1f38002b1cee (BED-01↔BTH-02): HORIZONTAL, L=0.474m, 3 openings

# %%
from thesis_package.ttl_to_json import save_ttl_as_json
from thesis_package.visualize import plot_plan_json

print("\nRegenerating...")
save_ttl_as_json(
    "../output/inferred_resplan_ttl/plan_00010_walls_back.ttl",
    "../output/inferred_resplan_json/plan_00010_walls_back.json",
)

print("\nVisualizing...")
plot_plan_json("../output/inferred_resplan_json/plan_00010_walls_back.json")
# Out:
# Regenerating...
#  IW-INF-8d11c96b11448bb9261ba18472aa71e3331cbd549a5cb11b65cb21b2624434f0 (BED-01↔LIV-01): VERTICAL, L=287.500m, 0 openings
#  IW-INF-f47f62cfe7c5816f89706a8b6cbaa76f9a26543573f2ce1ccf907819f4345579 (BED-01↔BTH-01): HORIZONTAL, L=81.500m, 0 openings
#  IW-INF-68259c0ee9cb8e86207f4a17ac7b459f74d186e6c33a1e9108132dff6f0ce453 (BED-01↔BTH-01): HORIZONTAL, L=81.500m, 0 openings
#
# Visualizing...
# <Axes: title={'center': 'Plan #10'}>

# %% [markdown]
# # Door

# %%
from thesis_package.ttl_to_json import save_ttl_as_json
from thesis_package.visualize import plot_plan_json


save_ttl_as_json(
    "../output/inferred_resplan_ttl/plan_00003_doors_back.ttl",
    "../output/inferred_resplan_json/plan_00003_doors_back.json",
)

ax = plot_plan_json("../output/inferred_resplan_json/plan_00003_doors_back.json",
                    show_wall_ids=True, show_ids=True)
# Out:
#     _shared_boundary_line: checking BED-01 ↔ LIV-01
#     _shared_boundary_line: intersection type=LineString, length=0.0
#     _shared_boundary_line: checking BED-03 ↔ LIV-01
#     _shared_boundary_line: intersection type=LineString, length=0.0
#     _shared_boundary_line: checking BED-02 ↔ LIV-01
#     _shared_boundary_line: intersection type=LineString, length=0.0

# %% [markdown]
# # Window

# %%
from thesis_package.ttl_to_json import save_ttl_as_json
from thesis_package.visualize import plot_plan_json


save_ttl_as_json(
    "../output/inferred_resplan_ttl/plan_00010_windows_back.ttl",
    "../output/inferred_resplan_json/plan_00010_windows_back.json",
)

ax = plot_plan_json("../output/inferred_resplan_json/plan_00010_windows_back.json",
                    show_wall_ids=True, show_ids=True)
# Out:
# === DEBUG WINDOW WI-INF-50374330e5e86941a59a97f5de7833fb5e6b5f029954b2ea42544b010727712f ===
#   Primary wall: EX-04
#   Primary bounds: (940.0, 237.0, 955.0, 314.0)
#   All host walls: ['EX-01', 'EX-04']
#   Secondary wall: EX-01
#   Secondary bounds: (652.0, 97.0, 667.0, 263.875)
#   Orientation: VERTICAL, thickness=15.000
#   Axis: [(947.5, 237.0), (947.5, 314.0)]
#   Distance to axis start: 280.500, to end: 284.943
#   Anchor: START (947.5, 237.0)
#   Window length: raw=280.500, clamped=2.400
#   Nearest on secondary: (667.0, 237.0)
#   Window line (V): (947.500, 237.000) → (947.500, 234.600)
#   ✅ Window created: area=36.000, geom_type=Polygon
#   ✅ Result keys: dict_keys(['type', 'coordinates'])
#   ✅ Result type: Polygon
#
# === DEBUG WINDOW WI-INF-50d2a7b7daf556e91867cf1d3e46d297c79a31a634906bd796f17268064c61d6 ===
#   Primary wall: EX-19
#   Primary bounds: (67.0, 97.0, 82.0, 390.0)
#   All host walls: ['EX-19', 'EX-17']
#   Secondary wall: EX-17
#   Secondary bounds: (361.0, 97.0, 376.0, 123.875)
#   Orientation: VERTICAL, thickness=15.000
#   Axis: [(74.5, 97.0), (74.5, 390.0)]
#   Distance to axis start: 286.500, to end: 391.030
#   Anchor: START (74.5, 97.0)
#   Window length: raw=286.500, clamped=2.400
#   Nearest on secondary: (361.0, 97.0)
#   Window line (V): (74.500, 97.000) → (74.500, 94.600)
#   ✅ Window created: area=36.000, geom_type=Polygon
#   ✅ Result keys: dict_keys(['type', 'coordinates'])
#   ✅ Result type: Polygon
#
# === DEBUG WINDOW WI-INF-a95e7fe2af15d58d4933b8a3f7f2a679fd95aa447a8c40b4400e84e27f1a6a62 ===
#   Primary wall: EX-15
#   Primary bounds: (354.0, 620.0, 376.0, 635.0)
#   All host walls: ['EX-16', 'EX-15']
#   Secondary wall: EX-16
#   Secondary bounds: (361.0, 515.125, 376.0, 620.0)
#   Orientation: HORIZONTAL, thickness=15.000
#   Axis: [(354.0, 627.5), (376.0, 627.5)]
#   Distance to axis start: 10.259, to end: 7.500
#   Anchor: END (376.0, 627.5)
#   Window length: raw=7.500, clamped=2.400
#   Nearest on secondary: (376.0, 620.0)
#   Window line (H): (376.000, 627.500) → (373.600, 627.500)
#   ✅ Window created: area=36.000, geom_type=Polygon
#   ✅ Result keys: dict_keys(['type', 'coordinates'])
#   ✅ Result type: Polygon
